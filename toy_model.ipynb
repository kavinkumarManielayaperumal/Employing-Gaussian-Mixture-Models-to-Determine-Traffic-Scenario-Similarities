# %% [markdown]
# <a href="https://colab.research.google.com/github/kavinkumarManielayaperumal/Toy-Model-for-Gaussian-Mixture-in-Traffic-Scenario-Group-Project./blob/main_toy/toy_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://kavinkumarManielayaperumal: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@github.com/kavinkumarManielayaperumal/Toy-Model-for-Gaussian-Mixture-in-Traffic-Scenario-Group-Project..git
# Out:
# fatal: destination path 'Toy-Model-for-Gaussian-Mixture-in-Traffic-Scenario-Group-Project.' already exists and is not an empty directory.

# %%
# %cd Toy-Model-for-Gaussian-Mixture-in-Traffic-Scenario-Group-Project.
# Out:
# /content/Toy-Model-for-Gaussian-Mixture-in-Traffic-Scenario-Group-Project.

# %%
# !git add .
# !git commit -m "for the test"
# !git push origin main_toy
# Out:
# Author identity unknown
#
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@d8b9502757ec.(none)')
# Everything up-to-date

# %%
# !git config --global user.name "kavinkumarManielayaperumal"
# !git config --global user.email "kavinkumarmanielayaperumal@gmail.com"
# !git add .
# !git commit -m "for the test"
# !git push origin main_toy
# Out:
# On branch main_toy
# Your branch is up to date with 'origin/main_toy'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
# !git add .
# !git commit -m "for the test"
# !git push origin main_toy
# Out:
# On branch main_toy
# Your branch is up to date with 'origin/main_toy'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
#for the test
def kav():
 num=[1,2,3,4]
 b=4
 for i in num:
   if i-1 > i:
     total=i+b
     num_total=max(total)
   return num_total

# %%
# !git add toy_model.ipynb
# !git commit -m "for the test"
# !git push origin main_toy
# !git branch -m main main_toy
# !git fetch origin
# !git branch -u origin/main_toy main_toy
# !git remote set-head origin -a
# Out:
# fatal: pathspec 'toy_model.ipynb' did not match any files
# On branch main_toy
# Your branch is up to date with 'origin/main_toy'.
#
# nothing to commit, working tree clean
# Everything up-to-date
# fatal: A branch named 'main_toy' already exists.
# Branch 'main_toy' set up to track remote branch 'main_toy' from 'origin'.
# origin/HEAD set to main_toy

# %%
# !ls
# !git status

# !ls 'notebooks (jupyter)'
# !git add 'notebooks (jupyter)/toy_model.ipynb'
# Out:
# 'documentation(doc)'   LICENSE	'notebooks (jupyter)'   README.md
# On branch main_toy
# Your branch is up to date with 'origin/main_toy'.
#
# nothing to commit, working tree clean
# toy_model.ipynb

# %%
# !git add 'notebooks (jupyter)/toy_model.ipynb'
# !git commit -m "Updated toy model notebook"
# !git push origin main_toy
# Out:
# On branch main_toy
# Your branch is up to date with 'origin/main_toy'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
for the
